# %%
# notebooks/01-data-exploration.ipynb (content outline)
"""
# AutoShield-K8s: Data Exploration

## 1. Load Generated Dataset
```python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
data = np.load('data/processed/train/dataset.npz')
X = data['X_train']
y = data['y_train']
feature_names = data['feature_names']
class_names = data['class_names']

print(f"Dataset shape: {X.shape}")
print(f"Classes: {class_names}")

# %%
## 1. Load Generated Dataset
```python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
